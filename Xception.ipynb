# %%
import cv2
import os
import datetime
import time
import numpy as np
import keras
import tensorflow.keras
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers, models

# from tensorflow.keras import layers
# import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.models import Sequential, Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.applications import ResNet50, ResNet152
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.layers import Input,UpSampling3D,Dense, Dropout,BatchNormalization 
from tensorflow.keras.layers import SeparableConv2D, Activation,DepthwiseConv2D,Flatten,concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D,Conv2DTranspose, Concatenate
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# from tensorflow.keras.callbacks import LearningRateScheduler,ModelCheckpointb
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
# Out:
# 2025-12-10 12:15:22.693674: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 12:15:22.741213: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-10 12:15:24.547390: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
labels = ['Newcastle', 'Other abnormal', 'Normal']
class_info = {0: 'Newcastle', 1: 'Other abnormal',2: 'Normal'}
img_size = 224

# %%
import glob

filename = glob.glob(r"/mnt/c/Poultry/po datasets/Dataset/Data/Newcastle/*.*")
print(len(filename))

filename = glob.glob(r"/mnt/c/Poultry/po datasets/Dataset/Data/Normal/*.*")
print(len(filename)) 

filename = glob.glob(r"/mnt/c/Poultry/po datasets/Dataset/Data/Other abnormal/*.*")
print(len(filename))
# Out:
# 339
# 1800
# 3940

# %%
BATCH_SIZE = 16
IMG_SIZE = (224, 224)

# %%
def get_data(data_dir, img_size=224):
    x, y = [], []
    
    # List of supported image file extensions
    supported_extensions = ('.bmp','.jpg')
    
    for label in os.listdir(data_dir):
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
        for img in os.listdir(path):
            try:
                # Check if the file has a supported image extension
                if img.lower().endswith(supported_extensions):
                    img_arr = cv2.imread(os.path.join(path, img))
                    img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                    resized_arr = cv2.resize(img_arr, (img_size, img_size), interpolation=cv2.INTER_LINEAR)
                    x.append(resized_arr)
                    y.append(class_num)
            except Exception as e:
                print(e)
    
    return x, y

# %%
data_x, data_y = get_data(r"/mnt/c/Poultry/po datasets/Dataset/Data")

# %%
test_x, test_y = get_data(r"/mnt/c/Poultry/po datasets/Dataset/Test dataset")
# (r"/mnt/c/Poultry/po datasets/Dataset/Data/Other abnormal/*.*")

# %%
from sklearn.model_selection import train_test_split
Train_x, Val_x, Train_y, Val_y = train_test_split(data_x, data_y, test_size=0.2)

# %%
Train_x, test_x, Train_y, test_y = train_test_split(Train_x, Train_y, test_size=0.1)

# %%
Train_x = np.array(Train_x)
Train_y = np.array(Train_y)
Val_x = np.array(Val_x)
Val_y = np.array(Val_y)
test_x = np.array(test_x)
test_y = np.array(test_y)

# %%
train_datagen = ImageDataGenerator()
val_datagen= ImageDataGenerator()
test_datagen = ImageDataGenerator()

# %%
Train_gen  = train_datagen.flow(Train_x, Train_y)
val_gen  = val_datagen.flow(Val_x, Val_y)
test_gen = test_datagen.flow(test_x, test_y)

# %%
plt.figure(figsize = (5,5))
plt.imshow(Train_x[0])
plt.title(labels[Train_y[0]])
# Out:
# Text(0.5, 1.0, 'Other abnormal')

# %%
print(Train_x.shape)
print(Val_x.shape)
print(test_x.shape)
# Out:
# (4376, 224, 224, 3)
# (1216, 224, 224, 3)
# (487, 224, 224, 3)

# %%
def build_model(input_shape):
    inputs = Input(shape=input_shape, name="input_image")
    Xception = tf.keras.applications.Xception(
        input_tensor = inputs, 
        weights="imagenet", include_top=False)
    
    x = Xception.get_layer('block14_sepconv2').output
    x = GlobalAveragePooling2D(name='gap')(x)
    output = Dense(3,activation='softmax')(x)
    return tf.keras.Model(inputs,output)

# %%
model = build_model(input_shape=(224,224,3))
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001),
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765358295.462986    8797 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3537 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_image         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 111, 111,  │        864 │ input_image[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, 111, 111,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, 111, 111,  │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 109, 109,  │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, 109, 109,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, 109, 109,  │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, 109, 109,  │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, 109, 109,  │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, 109, 109,  │          0 │ block2_sepconv1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, 109, 109,  │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, 109, 109,  │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 55, 55,    │      8,192 │ block1_conv2_act… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 55, 55,    │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 55, 55,    │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 55, 55,    │          0 │ block2_pool[0][0… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, 55, 55,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, 55, 55,    │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, 55, 55,    │          0 │ block3_sepconv1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, 55, 55,    │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, 55, 55,    │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 28, 28,    │     32,768 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ block3_pool[0][0… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, 28, 28,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, 28, 28,    │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, 28, 28,    │          0 │ block4_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, 28, 28,    │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, 28, 28,    │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │    186,368 │ add_1[0][0]       │
# │                     │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 14, 14,    │          0 │ block4_pool[0][0… │
# │                     │ 728)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, 14, 14,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, 14, 14,    │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, 14, 14,    │          0 │ block5_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, 14, 14,    │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, 14, 14,    │          0 │ block5_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, 14, 14,    │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 14, 14,    │          0 │ block5_sepconv3_… │
# │                     │ 728)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, 14, 14,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, 14, 14,    │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, 14, 14,    │          0 │ block6_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, 14, 14,    │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, 14, 14,    │          0 │ block6_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, 14, 14,    │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ block6_sepconv3_… │
# │                     │ 728)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, 14, 14,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, 14, 14,    │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, 14, 14,    │          0 │ block7_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, 14, 14,    │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, 14, 14,    │          0 │ block7_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, 14, 14,    │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ block7_sepconv3_… │
# │                     │ 728)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, 14, 14,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, 14, 14,    │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, 14, 14,    │          0 │ block8_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, 14, 14,    │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, 14, 14,    │          0 │ block8_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, 14, 14,    │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 14, 14,    │          0 │ block8_sepconv3_… │
# │                     │ 728)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, 14, 14,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, 14, 14,    │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, 14, 14,    │          0 │ block9_sepconv1_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, 14, 14,    │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, 14, 14,    │          0 │ block9_sepconv2_… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, 14, 14,    │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, 14, 14,    │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ block9_sepconv3_… │
# │                     │ 728)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, 14, 14,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, 14, 14,    │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, 14, 14,    │          0 │ block10_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, 14, 14,    │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, 14, 14,    │          0 │ block10_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, 14, 14,    │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 14, 14,    │          0 │ block10_sepconv3… │
# │                     │ 728)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, 14, 14,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, 14, 14,    │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, 14, 14,    │          0 │ block11_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, 14, 14,    │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, 14, 14,    │          0 │ block11_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, 14, 14,    │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ block11_sepconv3… │
# │                     │ 728)              │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, 14, 14,    │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, 14, 14,    │          0 │ block12_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, 14, 14,    │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, 14, 14,    │          0 │ block12_sepconv2… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, 14, 14,    │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, 14, 14,    │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 14, 14,    │          0 │ block12_sepconv3… │
# │                     │ 728)              │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, 14, 14,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, 14, 14,    │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, 14, 14,    │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, 14, 14,    │          0 │ block13_sepconv1… │
# │ (Activation)        │ 728)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, 14, 14,    │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, 14, 14,    │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 7,      │    745,472 │ add_10[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, 7, 7,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 7, 7,      │          0 │ block13_pool[0][… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, 7, 7,      │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, 7, 7,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, 7, 7,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, 7, 7,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 2048)      │          0 │ block14_sepconv2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      6,147 │ gap[0][0]         │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,859,435 (79.57 MB)
#  Trainable params: 20,809,003 (79.38 MB)
#  Non-trainable params: 50,432 (197.00 KB)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callback = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.3, patience=3, verbose=1, min_lr=1e-8 ),
    tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
    # tf.keras.callbacks.ModelCheckpoint(
        # filepath='new poultry dataset/classification_weights.h5',
        # save_best_only=True,save_weights_only=False,verbose=1)
           ]

# %%
history = model.fit(Train_gen,
                    validation_data = val_gen,
                    epochs=50,
                    batch_size = 8,
                   callbacks=callback)
# Out:
# Epoch 1/50
# 2025-12-10 12:18:33.012055: I external/local_xla/xla/service/service.cc:163] XLA service 0x742ecc0032c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-10 12:18:33.012102: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2025-12-10 12:18:33.446302: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-10 12:18:36.031545: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-12-10 12:18:40.639429: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:40.772419: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:40.899563: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:42.592887: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:42.751585: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:48.851069: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:49.808765: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=0} for conv (f32[32,728,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,728,28,28]{3,2,1,0}, f32[728,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=728, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-10 12:18:50.016485: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:50.027473: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.436035153s
# Trying algorithm eng3{k11=0} for conv (f32[32,728,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,728,28,28]{3,2,1,0}, f32[728,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=728, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-10 12:18:51.551287: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:51.760463: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:53.162290: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:53.423865: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:53.654993: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:54.724874: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:18:54.976524: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:19:05.280154: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:19:05.486253: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:19:06.037261: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.38GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-10 12:19:06.489700: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:19:06.698763: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-10 12:19:07.474381: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.40GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-10 12:19:07.726226: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1765358356.872199    8913 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-12-10 12:19:26.920329: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.01GiB (rounded to 4305601280)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-12-10 12:19:26.920428: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# 2025-12-10 12:19:26.920444: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 60, Chunks in use: 60. 15.0KiB allocated for chunks. 15.0KiB in use in bin. 2.3KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920451: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 13, Chunks in use: 13. 6.5KiB allocated for chunks. 6.5KiB in use in bin. 6.5KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920457: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 14, Chunks in use: 14. 15.0KiB allocated for chunks. 15.0KiB in use in bin. 14.0KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920464: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 108, Chunks in use: 107. 327.0KiB allocated for chunks. 323.2KiB in use in bin. 304.2KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920471: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 28, Chunks in use: 28. 136.2KiB allocated for chunks. 136.2KiB in use in bin. 112.2KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920477: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 7, Chunks in use: 7. 66.8KiB allocated for chunks. 66.8KiB in use in bin. 59.0KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920483: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 26, Chunks in use: 26. 667.0KiB allocated for chunks. 667.0KiB in use in bin. 662.2KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920489: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 11, Chunks in use: 11. 471.5KiB allocated for chunks. 471.5KiB in use in bin. 378.4KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920495: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 4, Chunks in use: 4. 316.0KiB allocated for chunks. 316.0KiB in use in bin. 272.0KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920500: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 3, Chunks in use: 3. 386.5KiB allocated for chunks. 386.5KiB in use in bin. 384.0KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920506: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 512.0KiB allocated for chunks. 512.0KiB in use in bin. 512.0KiB client-requested in use in bin.
# 2025-12-10 12:19:26.920512: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 3, Chunks in use: 3. 2.27MiB allocated for chunks. 2.27MiB in use in bin. 2.13MiB client-requested in use in bin.
# 2025-12-10 12:19:26.920520: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-12-10 12:19:26.920526: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 30, Chunks in use: 30. 64.43MiB allocated for chunks. 64.43MiB in use in bin. 63.12MiB client-requested in use in bin.
# 2025-12-10 12:19:26.920532: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 2, Chunks in use: 2. 12.00MiB allocated for chunks. 12.00MiB in use in bin. 12.00MiB client-requested in use in bin.
# 2025-12-10 12:19:26.920538: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 12.00MiB allocated for chunks. 12.00MiB in use in bin. 12.00MiB client-requested in use in bin.
# 2025-12-10 12:19:26.920549: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 39.22MiB allocated for chunks. 39.22MiB in use in bin. 30.38MiB client-requested in use in bin.
# 2025-12-10 12:19:26.920554: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-12-10 12:19:26.920559: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-12-10 12:19:26.920563: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-12-10 12:19:26.920568: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 1, Chunks in use: 0. 3.32GiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-12-10 12:19:26.920575: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1072] Bin for 4.01GiB was 256.00MiB, Chunk State:
# 2025-12-10 12:19:26.920587: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1078]   Size: 3.32GiB | Requested Size: 28.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 4.5KiB | Requested Size: 4.3KiB | in_use: 1 | bin_num: -1
# 2025-12-10 12:19:26.920591: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1085] Next region of size 3708813312
# 2025-12-10 12:19:26.920598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00000 of size 1280 next 1
# 2025-12-10 12:19:26.920602: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00500 of size 256 next 2
# 2025-12-10 12:19:26.920606: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00600 of size 256 next 3
# 2025-12-10 12:19:26.920610: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00700 of size 256 next 4
# 2025-12-10 12:19:26.920614: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00800 of size 256 next 5
# 2025-12-10 12:19:26.920617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00900 of size 256 next 7
# 2025-12-10 12:19:26.920621: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00a00 of size 256 next 8
# 2025-12-10 12:19:26.920624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00b00 of size 256 next 6
# 2025-12-10 12:19:26.920628: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00c00 of size 256 next 9
# 2025-12-10 12:19:26.920632: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00d00 of size 256 next 12
# 2025-12-10 12:19:26.920635: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00e00 of size 256 next 13
# 2025-12-10 12:19:26.920639: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c00f00 of size 256 next 14
# 2025-12-10 12:19:26.920642: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01000 of size 256 next 15
# 2025-12-10 12:19:26.920646: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01100 of size 256 next 18
# 2025-12-10 12:19:26.920649: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01200 of size 256 next 16
# 2025-12-10 12:19:26.920653: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01300 of size 256 next 17
# 2025-12-10 12:19:26.920656: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01400 of size 256 next 21
# 2025-12-10 12:19:26.920660: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01500 of size 256 next 22
# 2025-12-10 12:19:26.920666: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01600 of size 512 next 23
# 2025-12-10 12:19:26.920670: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01800 of size 512 next 26
# 2025-12-10 12:19:26.920674: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01a00 of size 512 next 24
# 2025-12-10 12:19:26.920678: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01c00 of size 256 next 280
# 2025-12-10 12:19:26.920682: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01d00 of size 256 next 25
# 2025-12-10 12:19:26.920685: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01e00 of size 256 next 29
# 2025-12-10 12:19:26.920689: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c01f00 of size 256 next 30
# 2025-12-10 12:19:26.920692: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02000 of size 512 next 34
# 2025-12-10 12:19:26.920696: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02200 of size 512 next 32
# 2025-12-10 12:19:26.920700: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02400 of size 512 next 31
# 2025-12-10 12:19:26.920703: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02600 of size 512 next 10
# 2025-12-10 12:19:26.920707: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02800 of size 256 next 282
# 2025-12-10 12:19:26.920711: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c02900 of size 3328 next 11
# 2025-12-10 12:19:26.920715: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c03600 of size 1024 next 51
# 2025-12-10 12:19:26.920720: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c03a00 of size 1024 next 52
# 2025-12-10 12:19:26.920724: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c03e00 of size 256 next 279
# 2025-12-10 12:19:26.920728: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c03f00 of size 256 next 270
# 2025-12-10 12:19:26.920732: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04000 of size 256 next 72
# 2025-12-10 12:19:26.920736: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04100 of size 256 next 53
# 2025-12-10 12:19:26.920740: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04200 of size 256 next 62
# 2025-12-10 12:19:26.920748: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04300 of size 256 next 63
# 2025-12-10 12:19:26.920751: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04400 of size 256 next 64
# 2025-12-10 12:19:26.920754: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04500 of size 256 next 65
# 2025-12-10 12:19:26.920758: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04600 of size 1024 next 66
# 2025-12-10 12:19:26.920761: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04a00 of size 1024 next 71
# 2025-12-10 12:19:26.920765: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c04e00 of size 1024 next 69
# 2025-12-10 12:19:26.920768: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05200 of size 1024 next 70
# 2025-12-10 12:19:26.920772: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05600 of size 256 next 74
# 2025-12-10 12:19:26.920775: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05700 of size 256 next 86
# 2025-12-10 12:19:26.920778: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05800 of size 256 next 76
# 2025-12-10 12:19:26.920781: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05900 of size 256 next 44
# 2025-12-10 12:19:26.920786: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c05a00 of size 4608 next 43
# 2025-12-10 12:19:26.920790: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c06c00 of size 1024 next 58
# 2025-12-10 12:19:26.920793: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c07000 of size 1024 next 56
# 2025-12-10 12:19:26.920796: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c07400 of size 1024 next 57
# 2025-12-10 12:19:26.920800: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c07800 of size 1024 next 287
# 2025-12-10 12:19:26.920804: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c07c00 of size 5376 next 61
# 2025-12-10 12:19:26.920808: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c09100 of size 3072 next 77
# 2025-12-10 12:19:26.920811: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c09d00 of size 3072 next 83
# 2025-12-10 12:19:26.920814: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c0a900 of size 3328 next 37
# 2025-12-10 12:19:26.920817: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c0b600 of size 4608 next 284
# 2025-12-10 12:19:26.920821: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c0c800 of size 26368 next 289
# 2025-12-10 12:19:26.920825: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c12f00 of size 34560 next 27
# 2025-12-10 12:19:26.920829: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1b600 of size 256 next 33
# 2025-12-10 12:19:26.920832: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1b700 of size 256 next 38
# 2025-12-10 12:19:26.920835: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1b800 of size 256 next 39
# 2025-12-10 12:19:26.920838: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1b900 of size 256 next 42
# 2025-12-10 12:19:26.920841: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1ba00 of size 512 next 40
# 2025-12-10 12:19:26.920844: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1bc00 of size 512 next 46
# 2025-12-10 12:19:26.920847: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1be00 of size 512 next 41
# 2025-12-10 12:19:26.920850: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1c000 of size 512 next 45
# 2025-12-10 12:19:26.920853: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1c200 of size 256 next 49
# 2025-12-10 12:19:26.920856: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1c300 of size 256 next 50
# 2025-12-10 12:19:26.920859: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1c400 of size 1024 next 36
# 2025-12-10 12:19:26.920862: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1c800 of size 512 next 283
# 2025-12-10 12:19:26.920866: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1ca00 of size 1792 next 35
# 2025-12-10 12:19:26.920869: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1d100 of size 3072 next 75
# 2025-12-10 12:19:26.920872: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1dd00 of size 3072 next 78
# 2025-12-10 12:19:26.920875: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1e900 of size 3072 next 68
# 2025-12-10 12:19:26.920878: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c1f500 of size 9216 next 67
# 2025-12-10 12:19:26.920881: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c21900 of size 3072 next 81
# 2025-12-10 12:19:26.920884: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c22500 of size 3072 next 82
# 2025-12-10 12:19:26.920896: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c23100 of size 256 next 87
# 2025-12-10 12:19:26.920899: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c23200 of size 256 next 90
# 2025-12-10 12:19:26.920902: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c23300 of size 3072 next 88
# 2025-12-10 12:19:26.920905: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c23f00 of size 3072 next 94
# 2025-12-10 12:19:26.920908: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c24b00 of size 3072 next 89
# 2025-12-10 12:19:26.920911: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c25700 of size 3072 next 93
# 2025-12-10 12:19:26.920915: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c26300 of size 4864 next 20
# 2025-12-10 12:19:26.920919: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c27600 of size 73728 next 19
# 2025-12-10 12:19:26.920923: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c39600 of size 3072 next 84
# 2025-12-10 12:19:26.920926: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3a200 of size 3072 next 99
# 2025-12-10 12:19:26.920929: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3ae00 of size 3072 next 97
# 2025-12-10 12:19:26.920932: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3ba00 of size 3072 next 100
# 2025-12-10 12:19:26.920935: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3c600 of size 3072 next 104
# 2025-12-10 12:19:26.920938: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3d200 of size 3072 next 98
# 2025-12-10 12:19:26.920941: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3de00 of size 3072 next 107
# 2025-12-10 12:19:26.920944: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3ea00 of size 3072 next 103
# 2025-12-10 12:19:26.920947: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c3f600 of size 3072 next 47
# 2025-12-10 12:19:26.920950: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c40200 of size 3072 next 111
# 2025-12-10 12:19:26.920953: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c40e00 of size 4864 next 101
# 2025-12-10 12:19:26.920956: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c42100 of size 26368 next 92
# 2025-12-10 12:19:26.920959: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c48800 of size 26368 next 91
# 2025-12-10 12:19:26.920963: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c4ef00 of size 3072 next 122
# 2025-12-10 12:19:26.920966: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c4fb00 of size 3072 next 120
# 2025-12-10 12:19:26.920969: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c50700 of size 3072 next 124
# 2025-12-10 12:19:26.920972: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c51300 of size 3072 next 127
# 2025-12-10 12:19:26.920975: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c51f00 of size 3072 next 121
# 2025-12-10 12:19:26.920978: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c52b00 of size 3072 next 128
# 2025-12-10 12:19:26.920981: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c53700 of size 3072 next 126
# 2025-12-10 12:19:26.920984: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c54300 of size 3072 next 133
# 2025-12-10 12:19:26.920987: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c54f00 of size 3072 next 131
# 2025-12-10 12:19:26.920990: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c55b00 of size 3072 next 136
# 2025-12-10 12:19:26.920994: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c56700 of size 3072 next 132
# 2025-12-10 12:19:26.920997: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c57300 of size 3072 next 140
# 2025-12-10 12:19:26.921000: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c57f00 of size 5888 next 48
# 2025-12-10 12:19:26.921004: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c59600 of size 32768 next 285
# 2025-12-10 12:19:26.921008: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c61600 of size 9216 next 60
# 2025-12-10 12:19:26.921011: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c63a00 of size 49920 next 106
# 2025-12-10 12:19:26.921015: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c6fd00 of size 26368 next 105
# 2025-12-10 12:19:26.921018: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c76400 of size 26368 next 112
# 2025-12-10 12:19:26.921021: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7cb00 of size 256 next 109
# 2025-12-10 12:19:26.921024: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7cc00 of size 256 next 80
# 2025-12-10 12:19:26.921027: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7cd00 of size 256 next 290
# 2025-12-10 12:19:26.921030: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7ce00 of size 3584 next 291
# 2025-12-10 12:19:26.921034: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7dc00 of size 3840 next 278
# 2025-12-10 12:19:26.921037: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7eb00 of size 3584 next 281
# 2025-12-10 12:19:26.921041: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c7f900 of size 40192 next 54
# 2025-12-10 12:19:26.921044: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c89600 of size 26368 next 194
# 2025-12-10 12:19:26.921047: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c8fd00 of size 26368 next 200
# 2025-12-10 12:19:26.921050: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c96400 of size 26368 next 206
# 2025-12-10 12:19:26.921054: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704c9cb00 of size 51968 next 55
# 2025-12-10 12:19:26.921058: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ca9600 of size 131072 next 59
# 2025-12-10 12:19:26.921061: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cc9600 of size 3072 next 113
# 2025-12-10 12:19:26.921064: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cca200 of size 3072 next 116
# 2025-12-10 12:19:26.921067: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ccae00 of size 3072 next 110
# 2025-12-10 12:19:26.921071: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ccba00 of size 3072 next 117
# 2025-12-10 12:19:26.921074: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ccc600 of size 3072 next 115
# 2025-12-10 12:19:26.921077: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ccd200 of size 37376 next 123
# 2025-12-10 12:19:26.921080: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cd6400 of size 26368 next 129
# 2025-12-10 12:19:26.921083: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cdcb00 of size 3072 next 138
# 2025-12-10 12:19:26.921086: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cdd700 of size 3072 next 142
# 2025-12-10 12:19:26.921089: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cde300 of size 3072 next 145
# 2025-12-10 12:19:26.921092: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cdef00 of size 3072 next 139
# 2025-12-10 12:19:26.921096: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cdfb00 of size 3072 next 148
# 2025-12-10 12:19:26.921099: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ce0700 of size 3072 next 144
# 2025-12-10 12:19:26.921102: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ce1300 of size 3072 next 152
# 2025-12-10 12:19:26.921105: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ce1f00 of size 4864 next 135
# 2025-12-10 12:19:26.921108: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ce3200 of size 26368 next 134
# 2025-12-10 12:19:26.921112: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ce9900 of size 26368 next 141
# 2025-12-10 12:19:26.921115: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf0000 of size 3072 next 150
# 2025-12-10 12:19:26.921118: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf0c00 of size 3072 next 154
# 2025-12-10 12:19:26.921121: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf1800 of size 3072 next 157
# 2025-12-10 12:19:26.921124: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf2400 of size 3072 next 151
# 2025-12-10 12:19:26.921127: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf3000 of size 3072 next 160
# 2025-12-10 12:19:26.921130: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf3c00 of size 3072 next 156
# 2025-12-10 12:19:26.921133: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf4800 of size 3072 next 164
# 2025-12-10 12:19:26.921136: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf5400 of size 4864 next 147
# 2025-12-10 12:19:26.921139: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cf6700 of size 26368 next 146
# 2025-12-10 12:19:26.921142: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704cfce00 of size 26368 next 153
# 2025-12-10 12:19:26.921145: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d03500 of size 3072 next 162
# 2025-12-10 12:19:26.921148: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d04100 of size 3072 next 166
# 2025-12-10 12:19:26.921151: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d04d00 of size 3072 next 169
# 2025-12-10 12:19:26.921154: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d05900 of size 3072 next 163
# 2025-12-10 12:19:26.921157: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d06500 of size 3072 next 172
# 2025-12-10 12:19:26.921160: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d07100 of size 3072 next 168
# 2025-12-10 12:19:26.921163: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d07d00 of size 3072 next 176
# 2025-12-10 12:19:26.921166: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d08900 of size 4864 next 159
# 2025-12-10 12:19:26.921170: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d09c00 of size 26368 next 158
# 2025-12-10 12:19:26.921173: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d10300 of size 26368 next 165
# 2025-12-10 12:19:26.921176: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d16a00 of size 3072 next 174
# 2025-12-10 12:19:26.921179: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d17600 of size 3072 next 178
# 2025-12-10 12:19:26.921182: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d18200 of size 3072 next 181
# 2025-12-10 12:19:26.921185: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d18e00 of size 3072 next 175
# 2025-12-10 12:19:26.921188: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d19a00 of size 3072 next 184
# 2025-12-10 12:19:26.921192: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d1a600 of size 3072 next 180
# 2025-12-10 12:19:26.921195: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d1b200 of size 3072 next 188
# 2025-12-10 12:19:26.921198: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d1be00 of size 4864 next 171
# 2025-12-10 12:19:26.921201: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d1d100 of size 26368 next 170
# 2025-12-10 12:19:26.921204: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d23800 of size 26368 next 177
# 2025-12-10 12:19:26.921207: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d29f00 of size 3072 next 186
# 2025-12-10 12:19:26.921210: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2ab00 of size 3072 next 190
# 2025-12-10 12:19:26.921213: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2b700 of size 3072 next 193
# 2025-12-10 12:19:26.921216: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2c300 of size 3072 next 187
# 2025-12-10 12:19:26.921219: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2cf00 of size 3072 next 195
# 2025-12-10 12:19:26.921222: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2db00 of size 3072 next 192
# 2025-12-10 12:19:26.921225: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2e700 of size 3072 next 199
# 2025-12-10 12:19:26.921228: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d2f300 of size 4864 next 183
# 2025-12-10 12:19:26.921231: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d30600 of size 26368 next 182
# 2025-12-10 12:19:26.921234: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d36d00 of size 26368 next 189
# 2025-12-10 12:19:26.921237: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d3d400 of size 3072 next 197
# 2025-12-10 12:19:26.921240: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d3e000 of size 3072 next 201
# 2025-12-10 12:19:26.921243: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d3ec00 of size 3072 next 204
# 2025-12-10 12:19:26.921246: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d3f800 of size 3072 next 198
# 2025-12-10 12:19:26.921249: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d40400 of size 3072 next 205
# 2025-12-10 12:19:26.921252: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d41000 of size 3072 next 203
# 2025-12-10 12:19:26.921255: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d41c00 of size 3072 next 210
# 2025-12-10 12:19:26.921258: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d42800 of size 3072 next 208
# 2025-12-10 12:19:26.921261: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d43400 of size 3072 next 211
# 2025-12-10 12:19:26.921264: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d44000 of size 3072 next 209
# 2025-12-10 12:19:26.921267: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d44c00 of size 3072 next 216
# 2025-12-10 12:19:26.921270: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d45800 of size 3072 next 214
# 2025-12-10 12:19:26.921273: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d46400 of size 3072 next 219
# 2025-12-10 12:19:26.921276: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d47000 of size 3072 next 215
# 2025-12-10 12:19:26.921279: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d47c00 of size 3072 next 223
# 2025-12-10 12:19:26.921282: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d48800 of size 26368 next 227
# 2025-12-10 12:19:26.921286: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d4ef00 of size 36864 next 246
# 2025-12-10 12:19:26.921290: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d57f00 of size 55296 next 255
# 2025-12-10 12:19:26.921294: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d65700 of size 65536 next 292
# 2025-12-10 12:19:26.921298: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d75700 of size 55296 next 296
# 2025-12-10 12:19:26.921301: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d82f00 of size 24576 next 298
# 2025-12-10 12:19:26.921305: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704d88f00 of size 133632 next 218
# 2025-12-10 12:19:26.921308: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704da9900 of size 26368 next 217
# 2025-12-10 12:19:26.921311: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db0000 of size 3072 next 73
# 2025-12-10 12:19:26.921315: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db0c00 of size 3072 next 212
# 2025-12-10 12:19:26.921318: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db1800 of size 3072 next 221
# 2025-12-10 12:19:26.921321: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db2400 of size 3072 next 225
# 2025-12-10 12:19:26.921324: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db3000 of size 3072 next 228
# 2025-12-10 12:19:26.921327: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db3c00 of size 3072 next 222
# 2025-12-10 12:19:26.921330: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db4800 of size 3072 next 231
# 2025-12-10 12:19:26.921333: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db5400 of size 4864 next 224
# 2025-12-10 12:19:26.921336: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db6700 of size 3072 next 233
# 2025-12-10 12:19:26.921339: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db7300 of size 3072 next 237
# 2025-12-10 12:19:26.921342: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db7f00 of size 256 next 234
# 2025-12-10 12:19:26.921345: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db8000 of size 256 next 239
# 2025-12-10 12:19:26.921349: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db8100 of size 4096 next 240
# 2025-12-10 12:19:26.921352: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704db9100 of size 4096 next 241
# 2025-12-10 12:19:26.921355: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dba100 of size 4096 next 242
# 2025-12-10 12:19:26.921359: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dbb100 of size 7424 next 230
# 2025-12-10 12:19:26.921362: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dbce00 of size 26368 next 229
# 2025-12-10 12:19:26.921365: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dc3500 of size 3072 next 235
# 2025-12-10 12:19:26.921368: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dc4100 of size 3072 next 236
# 2025-12-10 12:19:26.921371: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dc4d00 of size 3072 next 247
# 2025-12-10 12:19:26.921374: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dc5900 of size 3072 next 245
# 2025-12-10 12:19:26.921378: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dc6500 of size 26368 next 248
# 2025-12-10 12:19:26.921381: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dccc00 of size 4096 next 254
# 2025-12-10 12:19:26.921384: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dcdc00 of size 4096 next 252
# 2025-12-10 12:19:26.921388: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dcec00 of size 6144 next 249
# 2025-12-10 12:19:26.921392: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd0400 of size 4096 next 257
# 2025-12-10 12:19:26.921395: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd1400 of size 4096 next 250
# 2025-12-10 12:19:26.921398: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd2400 of size 6144 next 256
# 2025-12-10 12:19:26.921401: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd3c00 of size 16128 next 253
# 2025-12-10 12:19:26.921405: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd7b00 of size 256 next 259
# 2025-12-10 12:19:26.921408: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd7c00 of size 256 next 260
# 2025-12-10 12:19:26.921411: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd7d00 of size 256 next 261
# 2025-12-10 12:19:26.921414: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd7e00 of size 256 next 262
# 2025-12-10 12:19:26.921417: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd7f00 of size 6144 next 263
# 2025-12-10 12:19:26.921420: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dd9700 of size 6144 next 268
# 2025-12-10 12:19:26.921424: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ddaf00 of size 8192 next 265
# 2025-12-10 12:19:26.921428: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ddcf00 of size 33280 next 266
# 2025-12-10 12:19:26.921431: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de5100 of size 256 next 267
# 2025-12-10 12:19:26.921434: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de5200 of size 256 next 271
# 2025-12-10 12:19:26.921437: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de5300 of size 256 next 272
# 2025-12-10 12:19:26.921440: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de5400 of size 256 next 275
# 2025-12-10 12:19:26.921444: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de5500 of size 8192 next 273
# 2025-12-10 12:19:26.921447: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de7500 of size 8192 next 274
# 2025-12-10 12:19:26.921450: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704de9500 of size 4096 next 293
# 2025-12-10 12:19:26.921453: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dea500 of size 6144 next 295
# 2025-12-10 12:19:26.921456: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704debd00 of size 512 next 299
# 2025-12-10 12:19:26.921459: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704debf00 of size 4608 next 300
# 2025-12-10 12:19:26.921462: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ded100 of size 256 next 302
# 2025-12-10 12:19:26.921465: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ded200 of size 1024 next 303
# 2025-12-10 12:19:26.921468: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ded600 of size 256 next 306
# 2025-12-10 12:19:26.921471: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704ded700 of size 3072 next 309
# 2025-12-10 12:19:26.921475: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dee300 of size 256 next 311
# 2025-12-10 12:19:26.921478: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dee400 of size 256 next 316
# 2025-12-10 12:19:26.921481: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 704dee500 of size 256 next 312
# 2025-12-10 12:19:26.921484: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 704dee600 of size 3840 next 118
# ...
# 2025-12-10 12:19:26.921561: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7068a4200 of size 2119936 next 155
# 2025-12-10 12:19:26.921564: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 706aa9b00 of size 2119936 next 161
# 2025-12-10 12:19:26.921567: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 706caf400 of size 2119936 next 167
# 2025-12-10 12:19:26.921570: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 706eb4d00 of size 2119936 next 173
# 2025-12-10 12:19:26.921573: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7070ba600 of size 2119936 next 179
# 2025-12-10 12:19:26.921576: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7072bff00 of size 2119936 next 185
# 2025-12-10 12:19:26.921579: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7074c5800 of size 2119936 next 191
# 2025-12-10 12:19:26.921582: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7076cb100 of size 2119936 next 196
# 2025-12-10 12:19:26.921586: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7078d0a00 of size 2119936 next 202
# 2025-12-10 12:19:26.921589: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 707ad6300 of size 2119936 next 207
# 2025-12-10 12:19:26.921592: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 707cdbc00 of size 2119936 next 213
# 2025-12-10 12:19:26.921595: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 707ee1500 of size 2119936 next 220
# 2025-12-10 12:19:26.921598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7080e6e00 of size 2119936 next 226
# 2025-12-10 12:19:26.921601: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7082ec700 of size 2119936 next 232
# 2025-12-10 12:19:26.921604: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7084f2000 of size 2119936 next 238
# 2025-12-10 12:19:26.921607: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7086f7900 of size 2981888 next 244
# 2025-12-10 12:19:26.921611: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7089cf900 of size 2981888 next 243
# 2025-12-10 12:19:26.921614: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 708ca7900 of size 2981888 next 258
# 2025-12-10 12:19:26.921617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 708f7f900 of size 21856256 next 269
# 2025-12-10 12:19:26.921621: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70a457900 of size 6291456 next 251
# 2025-12-10 12:19:26.921624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70aa57900 of size 6291456 next 294
# 2025-12-10 12:19:26.921627: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70b057900 of size 12582912 next 297
# 2025-12-10 12:19:26.921631: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70bc57900 of size 26368 next 307
# 2025-12-10 12:19:26.921634: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70bc5e000 of size 2119936 next 308
# 2025-12-10 12:19:26.921637: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70be63900 of size 19267584 next 310
# 2025-12-10 12:19:26.921641: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 70d0c3900 of size 4608 next 317
# 2025-12-10 12:19:26.921645: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] Free  at 70d0c4b00 of size 3569595648 next 18446744073709551615
# 2025-12-10 12:19:26.921649: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1110]      Summary of in-use Chunks by size:
# 2025-12-10 12:19:26.921655: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 60 Chunks of size 256 totalling 15.0KiB
# 2025-12-10 12:19:26.921659: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 13 Chunks of size 512 totalling 6.5KiB
# 2025-12-10 12:19:26.921663: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 12 Chunks of size 1024 totalling 12.0KiB
# 2025-12-10 12:19:26.921667: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1280 totalling 1.2KiB
# 2025-12-10 12:19:26.921671: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 1792 totalling 1.8KiB
# 2025-12-10 12:19:26.921675: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 102 Chunks of size 3072 totalling 306.0KiB
# 2025-12-10 12:19:26.921679: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 3328 totalling 6.5KiB
# 2025-12-10 12:19:26.921683: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 3584 totalling 7.0KiB
# 2025-12-10 12:19:26.921687: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 3840 totalling 3.8KiB
# 2025-12-10 12:19:26.921690: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 8 Chunks of size 4096 totalling 32.0KiB
# 2025-12-10 12:19:26.921695: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 4 Chunks of size 4608 totalling 18.0KiB
# 2025-12-10 12:19:26.921699: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 8 Chunks of size 4864 totalling 38.0KiB
# 2025-12-10 12:19:26.921703: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 5376 totalling 5.2KiB
# 2025-12-10 12:19:26.921707: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 5888 totalling 5.8KiB
# 2025-12-10 12:19:26.921710: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 5 Chunks of size 6144 totalling 30.0KiB
# 2025-12-10 12:19:26.921714: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 7424 totalling 7.2KiB
# 2025-12-10 12:19:26.921718: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 8192 totalling 24.0KiB
# 2025-12-10 12:19:26.921722: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 9216 totalling 27.0KiB
# 2025-12-10 12:19:26.921726: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 16128 totalling 15.8KiB
# 2025-12-10 12:19:26.921729: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 24576 totalling 24.0KiB
# 2025-12-10 12:19:26.921733: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 25600 totalling 25.0KiB
# 2025-12-10 12:19:26.921737: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 24 Chunks of size 26368 totalling 618.0KiB
# 2025-12-10 12:19:26.921741: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 32768 totalling 32.0KiB
# 2025-12-10 12:19:26.921745: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 33280 totalling 32.5KiB
# 2025-12-10 12:19:26.921776: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 34560 totalling 33.8KiB
# 2025-12-10 12:19:26.921786: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 36864 totalling 36.0KiB
# 2025-12-10 12:19:26.921791: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 37376 totalling 36.5KiB
# 2025-12-10 12:19:26.921796: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 40192 totalling 39.2KiB
# 2025-12-10 12:19:26.921801: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 49920 totalling 48.8KiB
# 2025-12-10 12:19:26.921804: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 51968 totalling 50.8KiB
# 2025-12-10 12:19:26.921809: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 55296 totalling 162.0KiB
# 2025-12-10 12:19:26.921812: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 65536 totalling 64.0KiB
# 2025-12-10 12:19:26.921816: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 73728 totalling 144.0KiB
# 2025-12-10 12:19:26.921820: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 110592 totalling 108.0KiB
# 2025-12-10 12:19:26.921824: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 131072 totalling 256.0KiB
# 2025-12-10 12:19:26.921828: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 133632 totalling 130.5KiB
# 2025-12-10 12:19:26.921832: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 262144 totalling 512.0KiB
# 2025-12-10 12:19:26.921836: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 745472 totalling 1.42MiB
# 2025-12-10 12:19:26.921840: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 889088 totalling 868.2KiB
# 2025-12-10 12:19:26.921845: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 26 Chunks of size 2119936 totalling 52.56MiB
# 2025-12-10 12:19:26.921849: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 3 Chunks of size 2981888 totalling 8.53MiB
# 2025-12-10 12:19:26.921854: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 3494400 totalling 3.33MiB
# 2025-12-10 12:19:26.921858: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 6291456 totalling 12.00MiB
# 2025-12-10 12:19:26.921862: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 12582912 totalling 12.00MiB
# 2025-12-10 12:19:26.921866: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 19267584 totalling 18.38MiB
# 2025-12-10 12:19:26.921870: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 21856256 totalling 20.84MiB
# 2025-12-10 12:19:26.921875: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] Sum Total of in-use chunks: 132.76MiB
# 2025-12-10 12:19:26.921884: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119] Total bytes in pool: 3708813312 memory_limit_: 3708813312 available bytes: 0 curr_region_allocation_bytes_: 7417626624
# 2025-12-10 12:19:26.921894: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1124] Stats:
# Limit:                      3708813312
# InUse:                       139213824
# MaxInUse:                   2988238848
# NumAllocs:                        2963
# MaxAllocSize:               2392473600
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-12-10 12:19:26.921912: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ****________________________________________________________________________________________________
# 2025-12-10 12:19:26.926076: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4305601080 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 history = model.fit(Train_gen,
#       2                     validation_data = val_gen,
#       3                     epochs=50,
#       4                     batch_size = 8,
#       5                    callbacks=callback)
#
# File ~/tf-gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/tf-gpu/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_8797/1698632019.py", line 1, in <module>
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 399, in fit
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 241, in function
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 154, in multi_step_on_iterator
#
#   File "/home/yordi/tf-gpu/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
# Out of memory while trying to allocate 4305601080 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_31669]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train acc','validation acc'])
plt.ylabel('acu')
plt.xlabel('epochs')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history[ 'val_loss'])
plt.legend(['train loss','validation loss'])
plt.ylabel('loss')
plt.xlabel('epochs')
plt.show()

# %%
BATCH = 4
test_dataset = test_datagen.flow(test_x, test_y)

test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1


model.evaluate(test_dataset, steps=test_steps)

# %%
predictions = model.predict(test_x)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
pred_prob = model.predict(test_x)
# pred_prob = restnet.predict_proba(Val_x)

# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 3

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(test_y, pred_prob[:,i], pos_label=i)


plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Newcastle')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Normal')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Other abnormal')

plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=300);

# %%
def decode_prediction(pred):
  # This function thresholds a probability to produce a prediction
  pred = tf.where(pred < 0.5, 0, 1)
  return pred.numpy()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = test_x[58]
label = test_y[58]
print('class_label_idx = ', label)
# Make predictions for the input image
predictions = model.predict(np.expand_dims(img, axis=0))[0]
N = 1
# Get the top N predicted classes and their probabilities
top_classes = np.argsort(predictions)[-N:][::-1]
top_probs = predictions[top_classes]

class_labels = ['Newcastle', 'Normal', 'Other abnormal']
print (class_labels)
# Display the image
plt.figure(figsize=(3, 3))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Display the top predicted classes and their probabilities
for i in range(len(top_classes)):
    class_idx = top_classes[i]
    class_prob = top_probs[i]
    class_label = class_labels[class_idx]
    plt.text(10, 10 + i * 20, f"{class_label}: {class_prob:.2f}", color='Black', fontsize=8)

plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Define a list of images and their corresponding labels
images = test_x[0:10]
labels = test_y[0:10]
class_labels = ['Newcastle', 'Normal', 'Other abnormal']  # Define your class labels
print (class_labels)
# Create a subplot grid
rows = 1  # Only one row for horizontal display
cols = len(images)  # One column per image

plt.figure(figsize=(15, 5))  # Adjust the figure size as needed

# Iterate through each image and label
for i in range(len(images)):
    img = images[i]
    label = labels[i]
    print('class_Truelabel_idx = ', label)
    # Make predictions for the input image
    predictions = model.predict(np.expand_dims(img, axis=0))[0]
    N = 1  # Number of top classes to display

    # Get the top N predicted classes and their probabilities
    top_classes = np.argsort(predictions)[-N:][::-1]
    top_probs = predictions[top_classes]

    # Create a subplot for each image
    plt.subplot(rows, cols, i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')

    # Display the top predicted classes and their probabilities below the image
    for j in range(len(top_classes)):
        class_idx = top_classes[j]
        class_prob = top_probs[j]
        class_label = class_labels[class_idx]
        plt.text(0.5, -0.2 - j * 0.2, f"{class_label}: {class_prob:.2f}", color='Black', fontsize=12,
                 transform=plt.gca().transAxes)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Model



def GradCam(model, img_array, layer_name, eps=1e-8):
    '''
    Creates a grad-cam heatmap given a model and a layer name contained with that model
    

    Args:
      model: tf model
      img_array: (img_width x img_width) numpy array
      layer_name: str


    Returns 
      uint8 numpy array with shape (img_height, img_width)

    '''

    gradModel = Model(
			inputs=[model.inputs],
			outputs=[model.get_layer(layer_name).output,
				model.output])
    
    with tf.GradientTape() as tape:
			# cast the image tensor to a float-32 data type, pass the
			# image through the gradient model, and grab the loss
			# associated with the specific class index
      inputs = tf.cast(img_array, tf.float32)
      (convOutputs, predictions) = gradModel(inputs)
      loss = predictions[:, 0]
		# use automatic differentiation to compute the gradients
    grads = tape.gradient(loss, convOutputs)
    
    # compute the guided gradients
    castConvOutputs = tf.cast(convOutputs > 0, "float32")
    castGrads = tf.cast(grads > 0, "float32")
    guidedGrads = castConvOutputs * castGrads * grads
		# the convolution and guided gradients have a batch dimension
		# (which we don't need) so let's grab the volume itself and
		# discard the batch
    convOutputs = convOutputs[0]
    guidedGrads = guidedGrads[0]
    # compute the average of the gradient values, and using them
		# as weights, compute the ponderation of the filters with
		# respect to the weights
    weights = tf.reduce_mean(guidedGrads, axis=(0, 1))
    cam = tf.reduce_sum(tf.multiply(weights, convOutputs), axis=-1)
  
    # grab the spatial dimensions of the input image and resize
		# the output class activation map to match the input image
		# dimensions
    (w, h) = (img_array.shape[2], img_array.shape[1])
    heatmap = cv2.resize(cam.numpy(), (w, h))
		# normalize the heatmap such that all values lie in the range
		# [0, 1], scale the resulting values to the range [0, 255],
		# and then convert to an unsigned 8-bit integer
    numer = heatmap - np.min(heatmap)
    denom = (heatmap.max() - heatmap.min()) + eps
    heatmap = numer / denom
    # heatmap = (heatmap * 255).astype("uint8")
		# return the resulting heatmap to the calling function
    return heatmap


def sigmoid(x, a, b, c):
    return c / (1 + np.exp(-a * (x-b)))

def superimpose(img_bgr, cam, thresh, emphasize=False):
    
    '''
    Superimposes a grad-cam heatmap onto an image for model interpretation and visualization.
    

    Args:
      image: (img_width x img_height x 3) numpy array
      grad-cam heatmap: (img_width x img_width) numpy array
      threshold: float
      emphasize: boolean

    Returns 
      uint8 numpy array with shape (img_height, img_width, 3)

    '''
    heatmap = cv2.resize(cam, (img_bgr.shape[1], img_bgr.shape[0]))
    if emphasize:
        heatmap = sigmoid(heatmap, 50, thresh, 1)
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    
    hif = .8
    superimposed_img = heatmap * hif + img_bgr
    superimposed_img = np.minimum(superimposed_img, 255.0).astype(np.uint8)  # scale 0 to 255  
    superimposed_img_rgb = cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB)
    
    return superimposed_img_rgb

# %%
## Grad-CAM heatmap for the last convolutional layer in the model, Conv_1

layer_name = 'block_16_project'
grad_cam=GradCam(model,np.expand_dims(img, axis=0),layer_name)
grad_cam_superimposed = superimpose(img, grad_cam, 0.5, emphasize=True)


plt.figure(figsize=(12, 3))
ax = plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')
ax = plt.subplot(1, 2, 2)
plt.imshow(grad_cam_superimposed)
plt.axis('off')
plt.title('top_conv Grad-CAM heat-map')
plt.tight_layout()

# %%
## Grad-CAM heatmap for the block_4_expand_relu
## This layer shows how the model begins learning concepts in the image

plt.figure(figsize=(12, 5))
ax = plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')
ax = plt.subplot(1, 2, 2)
grad_cam = GradCam(model, np.expand_dims(img, axis=0), 'Conv_1')
grad_cam_emphasized = superimpose(img, grad_cam, 0.5, emphasize=False)
plt.imshow(grad_cam_emphasized)
plt.axis('off')
plt.title('Conv_1')
plt.tight_layout()

# %%
# Import necessary libraries
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import ConfusionMatrixDisplay


# Assuming you have already trained and have your model defined as 'model'

# Predict probabilities for test set
yhat_probs = model.predict(test_x, verbose=0)

# Predict crisp classes for test set by selecting the class with the highest probability
yhat_classes = np.argmax(yhat_probs, axis=1)

# Accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(test_y, yhat_classes)
print('Accuracy: %f' % accuracy)

# Precision: tp / (tp + fp)
precision = precision_score(test_y, yhat_classes, average='weighted')  # 'weighted' for multi-class
print('Precision: %f' % precision)

# Recall: tp / (tp + fn)
recall = recall_score(test_y, yhat_classes, average='weighted')  # 'weighted' for multi-class
print('Recall: %f' % recall)

# F1 Score: 2 * (precision * recall) / (precision + recall)
f1 = f1_score(test_y, yhat_classes, average='weighted')  # 'weighted' for multi-class
print('F1 score: %f' % f1)

# Cohen's Kappa
kappa = cohen_kappa_score(test_y, yhat_classes)
print('Cohen\'s kappa: %f' % kappa)

# Confusion Matrix
matrix = confusion_matrix(test_y, yhat_classes)
print('Confusion Matrix:')
print(matrix)
disp = ConfusionMatrixDisplay(confusion_matrix=matrix,display_labels=['Newcastle', 'Normal', 'Other abnormal'])
disp.plot()

plt.savefig('confusionmatrix.png')
plt.show()

# %%
class_report = classification_report(test_y, yhat_classes)
print('Classification Report:\n', class_report)

# %%
# Visualize Grad-CAM and CAM for a sample image (change the index as needed)
sample_index = 1  # Change this to the index of the image you want to visualize
sample_image = test_x[sample_index]
sample_true_label = test_y[sample_index]

# Create a sub-model that extracts the output of the final convolutional layer
last_conv_layer = model.get_layer('Conv_1')
grad_model = Model(inputs=model.inputs, outputs=[last_conv_layer.output, model.output])

# Compute the gradient of the top predicted class with respect to the output feature map of the last conv layer
with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(np.expand_dims(sample_image, axis=0))
    loss = predictions[:, sample_true_label]

grads = tape.gradient(loss, conv_outputs)[0]
gradient_weights = tf.reduce_mean(grads, axis=(0, 1))

# Generate the CAM heatmap
cam = np.dot(conv_outputs[0], gradient_weights.numpy())

# Resize CAM to the original image size
cam = cv2.resize(cam, (sample_image.shape[1], sample_image.shape[0]))
cam = np.maximum(cam, 0)  # Apply ReLU to exclude negative values
cam = cam / cam.max()  # Normalize between 0 and 1

# Convert the CAM heatmap to a colormap
heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)

# Superimpose the heatmap on the original image
superimposed_img = heatmap * 0.4 + (sample_image * 255).astype(np.uint8)
superimposed_img = np.minimum(superimposed_img, 255).astype(np.uint8)

# Display the original image, Grad-CAM, and CAM
plt.figure(figsize=(12, 4))
plt.subplot(131)
plt.title('Original Image')
plt.imshow(sample_image)
plt.axis('off')

plt.subplot(132)
plt.title('Grad-CAM')
plt.imshow(superimposed_img)
plt.axis('off')

plt.subplot(133)
plt.title('Class Activation Map (CAM)')
plt.imshow(cam, cmap='jet')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
model.save('poultry1.h5')

# %%
tensorboard --logdir=logs/fit
